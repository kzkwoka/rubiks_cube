# %%
# %matplotlib notebook
import numpy as np
import cv2
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


images_path = './images/'
# scaling factor from opencv to (360deg,100%,100%) H*2,S/255*100,V/255*100

# %%
blues = []
for i in range(1,7):
    name = f"{i}.jpg"
    image = cv2.imread(images_path + name )[230:300,250:310]
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mean = cv2.mean(hsv)
    blues.append([mean[0]*2,mean[1]/255*100,mean[2]/255*100])
blues = np.array(blues)
print(blues)
# Out:
# [[195.91571429  97.09906629  91.60280112]
#  [202.2         97.90905696  83.94799253]
#  [209.13380952  98.54537815  64.79122316]
#  [207.64666667  98.24276377  59.04621849]
#  [211.22571429  98.69915966  41.91988796]
#  [214.52380952  99.07824463  28.11456583]]

# %%
reds = []
for i in range(1,7):
    name = f"{i}.jpg"
    image = cv2.imread(images_path + name )[230:300,170:220]
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mean = cv2.mean(hsv)
    reds.append([mean[0]*2,mean[1]/255*100,mean[2]/255*100])
reds = np.array(reds) ## weird pink results
print(reds)
# Out:
# [[331.71942857  78.83753501  96.37109244]
#  [326.25428571  85.25691877  92.19585434]
#  [316.69257143  90.4952381   76.82487395]
#  [320.54514286  89.52403361  68.77243697]
#  [251.29257143  92.28806723  53.15114846]
#  [237.53485714  94.19619048  37.40268908]]

# %%
whites = []
for i in range(1,7):
    name = f"{i}.jpg"
    image = cv2.imread(images_path + name )[240:290,80:140]
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mean = cv2.mean(hsv)
    whites.append([mean[0]*2,mean[1]/255*100,mean[2]/255*100])
whites = np.array(whites)
print(whites)
# Out:
# [[293.82         2.61973856  90.58496732]
#  [294.04933333   2.68013072  90.44980392]
#  [293.536        2.76183007  89.79150327]
#  [295.96866667   2.42810458  79.24562092]
#  [295.39133333   4.46993464  67.78849673]
#  [294.69933333   6.84705882  43.3130719 ]]

# %%
greens = []
for i in range(1,7):
    name = f"{i}.jpg"
    image = cv2.imread(images_path + name )[150:200,170:220]
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mean = cv2.mean(hsv)
    greens.append([mean[0]*2,mean[1]/255*100,mean[2]/255*100])
greens = np.array(greens)
print(greens)
# Out:
# [[146.5336      98.10478431  76.42196078]
#  [142.8696      98.5747451   60.26196078]
#  [139.056       98.69113725  36.32564706]
#  [139.8912      98.83027451  34.57458824]
#  [137.8872      99.27388235  22.20078431]
#  [136.8208      98.42509804  13.61223529]]

# %%
oranges = []
for i in range(1,7):
    name = f"{i}.jpg"
    image = cv2.imread(images_path + name )[50:110,170:220]
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mean = cv2.mean(hsv)
    oranges.append([mean[0]*2,mean[1]/255*100,mean[2]/255*100])
oranges = np.array(oranges)
print(oranges)
# Out:
# [[29.28533333 98.69084967 98.99633987]
#  [24.13333333 99.02614379 98.24379085]
#  [19.41666667 99.31254902 94.44679739]
#  [20.39333333 99.15803922 84.9820915 ]
#  [14.44933333 99.52993464 74.7930719 ]
#  [10.05733333 99.46771242 54.96509804]]

# %%
yellows = []
for i in range(1,7):
    name = f"{i}.jpg"
    image = cv2.imread(images_path + name )[50:110,250:310]
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mean = cv2.mean(hsv)
    yellows.append([mean[0]*2,mean[1]/255*100,mean[2]/255*100])
yellows = np.array(yellows)
print(yellows)
# Out:
# [[49.84111111 98.92745098 94.07145969]
#  [49.37277778 98.99705882 92.66568627]
#  [47.82888889 98.89858388 90.30708061]
#  [49.07055556 98.95925926 79.70577342]
#  [41.885      99.28529412 68.60958606]
#  [37.07944444 99.36165577 45.3171024 ]]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(yellows[:,0],yellows[:,2],yellows[:,1], c='yellow', marker='o')
ax.scatter(oranges[:,0],oranges[:,2],oranges[:,1], c='orange', marker='o')
ax.scatter(reds[:,0],reds[:,2],reds[:,1], c='r', marker='o')
ax.scatter(greens[:,0],greens[:,2],greens[:,1], c='g', marker='o')
ax.scatter(blues[:,0],blues[:,2],blues[:,1], c='b', marker='o')
ax.scatter(whites[:,0],whites[:,2],whites[:,1], c='black', marker='o')
ax.set_xlabel('H')
ax.set_ylabel('V')
ax.set_zlabel('S')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
